# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("DemoSparkApp").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/12 05:07:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/12 05:07:32 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
data = [("Hardik", 22), ("Rahul", 21), ("Aman", 23)]

df = spark.createDataFrame(data, ["Name", "Age"])

df.show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Hardik| 22|
# | Rahul| 21|
# |  Aman| 23|
# +------+---+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Spark Session
spark = SparkSession.builder.appName("EmployeeData").getOrCreate()

# Data
data = [
    (1, "Alice", "Engineering", 75000, 25),
    (2, "Bob", "Marketing", 60000, 30),
    (3, "Charlie", "Engineering", 80000, 35),
    (4, "David", "Sales", 65000, 28),
    (5, "Eve", "Marketing", 70000, 32)
]

# Columns
columns = ["Id", "Name", "Department", "Salary", "Age"]

# DataFrame Create
df = spark.createDataFrame(data, columns)

# Bonus Column (10% of Salary)
df = df.withColumn("Bonus", col("Salary") * 0.10)

# Show Result
df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/12 05:50:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/12 05:50:32 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# +---+-------+-----------+------+---+------+
# | Id|   Name| Department|Salary|Age| Bonus|
# +---+-------+-----------+------+---+------+
# |  1|  Alice|Engineering| 75000| 25|7500.0|
# |  2|    Bob|  Marketing| 60000| 30|6000.0|
# |  3|Charlie|Engineering| 80000| 35|8000.0|
# |  4|  David|      Sales| 65000| 28|6500.0|
# |  5|    Eve|  Marketing| 70000| 32|7000.0|
# +---+-------+-----------+------+---+------+
# 26/06/12 05:50:44 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
df.write.mode("overwrite").csv("output/employeesTable",header=True)

# %%
df.toPandas().to_csv(
    "output/employees123.csv",
    index=False
)

# %%
df.createOrReplaceTempView("employees")

# %%
result =spark.sql("""SELECT *FROM employees WHERE salary >70000""").show()
# Out:
# +---+-------+-----------+------+---+------+
# | Id|   Name| Department|Salary|Age| Bonus|
# +---+-------+-----------+------+---+------+
# |  1|  Alice|Engineering| 75000| 25|7500.0|
# |  3|Charlie|Engineering| 80000| 35|8000.0|
# +---+-------+-----------+------+---+------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, desc, sum, avg

# Initialize
spark = SparkSession.builder.appName("ImportFileApp").getOrCreate()

# %%
df.filter(
    (col("Department") == "Engineering") &
    (col("Salary") == "80000")
).show()
# Out:
# +---+-------+-----------+------+---+------+
# | Id|   Name| Department|Salary|Age| Bonus|
# +---+-------+-----------+------+---+------+
# |  3|Charlie|Engineering| 80000| 35|8000.0|
# +---+-------+-----------+------+---+------+
